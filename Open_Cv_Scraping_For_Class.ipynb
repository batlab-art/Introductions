# %% [markdown]
# <a href="https://colab.research.google.com/github/batlab-art/Introductions/blob/master/Open_Cv_Scraping_For_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# !pip install icrawler
# Out:
# Collecting icrawler
#   Downloading https://files.pythonhosted.org/packages/89/de/71d154b1fe181ee1a4afae5d10451856ef4689b3fd72d93cc55f31d2886a/icrawler-0.6.3-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.3

# %% [markdown]
# # Fetch Images
# ### BingImageCrawler:
# **Type** – “photo”, “clipart”, “linedrawing”, “transparent”, “animated"
# **Color** – “color”, “blackandwhite”, “red”, “orange”, “yellow”, “green”, “teal”, “blue”, “purple”, “pink”, “white”, “gray”, “black”, “brown
# **Size** – “large”, “medium”, “small” or larger than a given size (e.g. “>640x480”).
# **License** – “creativecommons”, “publicdomain”, “noncommercial”, “commercial”, “noncommercial,modify”, “commercial,modify”.
# **Layout** – “square”, “wide”, “tall”.
# **People** – “face”, “portrait”.
# **Date** – “pastday”, “pastweek”, “pastmonth”, “pastyear”.
#
# https://icrawler.readthedocs.io/en/latest/builtin.html

# %%
# !rm /content/download/*

from icrawler.builtin import BingImageCrawler

keywordText = 'blue red green'  #@param {type: "string"}
num_images =   32#@param {type: "number"}
output_directory = '/content/download/'  #@param {type: "string"}


bing_crawler = BingImageCrawler(storage={'root_dir': 'download'})
bing_crawler.crawl(keyword=keywordText, max_num=num_images)
# Out:
# 2020-09-30 13:04:03,626 - INFO - icrawler.crawler - start crawling...
# 2020-09-30 13:04:03,627 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-30 13:04:03,633 - INFO - feeder - thread feeder-001 exit
# 2020-09-30 13:04:03,633 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-30 13:04:03,639 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-30 13:04:04,050 - INFO - parser - parsing result page https://www.bing.com/images/async?q=blue red green&first=0
# 2020-09-30 13:04:04,979 - INFO - downloader - image #1	https://simplecodetips.com/wp-content/uploads/2017/01/red-green-blue-yellow-canvas.jpg
# 2020-09-30 13:04:05,620 - INFO - downloader - image #2	http://www.esri.com/news/arcuser/0807/graphics/nongeo_4-lg.jpg
# 2020-09-30 13:04:13,218 - INFO - downloader - image #20	https://thumbs.dreamstime.com/z/background-red-blue-yellow-green-stains-7481239.jpg
# 2020-09-30 13:04:14,332 - INFO - downloader - image #21	https://dojft4652t1in.cloudfront.net/wp-content/uploads/LE-5M-RGB-WC-800x800.jpg
# 2020-09-30 13:04:15,645 - INFO - downloader - image #22	https://img3.goodfon.com/wallpaper/nbig/1/7f/wave-energy-red-yellow-green.jpg
# 2020-09-30 13:04:15,663 - INFO - downloader - image #23	https://thumbs.dreamstime.com/b/background-red-blue-yellow-green-stains-7481239.jpg
# 2020-09-30 13:04:15,718 - INFO - downloader - image #24	https://i.ytimg.com/vi/UgNCraSjPqo/hqdefault.jpg
# 2020-09-30 13:04:17,353 - INFO - downloader - image #25	https://cdn.allwallpaper.in/wallpapers/1920x1080/9112/green-abstract-blue-red-spectrum-rainbows-lines-colors-1920x1080-wallpaper.jpg
# 2020-09-30 13:04:18,219 - INFO - downloader - image #26	https://www.dizzysquirrel.com/wp-content/uploads/2015/08/rygb-icon.jpg
# 2020-09-30 13:04:18,884 - INFO - downloader - image #27	http://www.thebroad.org/sites/default/files/art/kelly_greenbluered.jpg
# 2020-09-30 13:04:19,722 - INFO - parser - no more page urls for thread parser-001 to parse
# 2020-09-30 13:04:19,724 - INFO - parser - thread parser-001 exit
# 2020-09-30 13:04:19,843 - INFO - downloader - image #28	https://wallup.net/wp-content/uploads/2017/11/17/271024-red-stripes-green-blue-orange-748x561.jpg
# 2020-09-30 13:04:20,314 - INFO - downloader - image #29	http://cdn.davemorrowphotography.com/wp-content/uploads/2016/12/Color-Theory-Photography-Guide-Shades-of-Red-Green-and-Blue-Hues-900x450.jpg
# 2020-09-30 13:04:20,606 - INFO - downloader - image #30	https://urbannight.files.wordpress.com/2012/03/red-light-green-light.jpg
# 2020-09-30 13:04:20,624 - INFO - downloader - image #31	https://thumbs.dreamstime.com/z/red-green-blue-bulbs-10520089.jpg
# 2020-09-30 13:04:25,627 - INFO - downloader - no more download task for thread downloader-001
# 2020-09-30 13:04:25,628 - INFO - downloader - thread downloader-001 exit
# 2020-09-30 13:04:25,670 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# # Process Images

# %%
import cv2
import matplotlib.pyplot as plt

# List Files
inputFiles = os.listdir(output_directory)

# Add Code to handle Files

# Display Results
fig, axs = plt.subplots(7, 3, figsize=(20, 20))
fig.subplots_adjust(hspace = .5, wspace=.001)
axarr = axs.ravel()

for i in range(21):
  tmp = cv2.imread(output_directory + inputFiles[i])
  tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)
  axarr[i].imshow(tmp)
  axarr[i].axis('off')
