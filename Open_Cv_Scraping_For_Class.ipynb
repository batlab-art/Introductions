# %% [markdown]
# <a href="https://colab.research.google.com/github/batlab-art/Introductions/blob/master/Open_Cv_Scraping_For_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# !pip install icrawler
# Out:
# Collecting icrawler
#   Downloading https://files.pythonhosted.org/packages/89/de/71d154b1fe181ee1a4afae5d10451856ef4689b3fd72d93cc55f31d2886a/icrawler-0.6.3-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.3

# %% [markdown]
# # Fetch Images
# ### BingImageCrawler:
# **Type** – “photo”, “clipart”, “linedrawing”, “transparent”, “animated"
# **Color** – “color”, “blackandwhite”, “red”, “orange”, “yellow”, “green”, “teal”, “blue”, “purple”, “pink”, “white”, “gray”, “black”, “brown
# **Size** – “large”, “medium”, “small” or larger than a given size (e.g. “>640x480”).
# **License** – “creativecommons”, “publicdomain”, “noncommercial”, “commercial”, “noncommercial,modify”, “commercial,modify”.
# **Layout** – “square”, “wide”, “tall”.
# **People** – “face”, “portrait”.
# **Date** – “pastday”, “pastweek”, “pastmonth”, “pastyear”.
#
# https://icrawler.readthedocs.io/en/latest/builtin.html

# %%
# !rm /content/download/*

from icrawler.builtin import BingImageCrawler

# הגדרת משתנים עבור פרמטרים לחיפוש תמונות
#

keywordText = 'yellow round thing'  #@param {type: "string"}
num_images =   32 #@param {type: "number"}
directory = 'download'  #@param {type: "string"}

# ביצוע חיפוש והורדת תמונות מבינג
#

bing_crawler = BingImageCrawler(storage={'root_dir': directory})
bing_crawler.crawl(keyword=keywordText, max_num=num_images)

output_directory = '/content/' + directory + '/'
# Out:
# rm: cannot remove '/content/download/*': No such file or directory
# 2020-10-01 09:32:35,271 - INFO - icrawler.crawler - start crawling...
# 2020-10-01 09:32:35,272 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-10-01 09:32:35,278 - INFO - feeder - thread feeder-001 exit
# 2020-10-01 09:32:35,279 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-10-01 09:32:35,285 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-10-01 09:32:35,675 - INFO - parser - parsing result page https://www.bing.com/images/async?q=yellow round thing&first=0
# 2020-10-01 09:32:36,061 - INFO - downloader - image #1	https://ogtstore.com/wp-content/uploads/2017/03/N245609.jpg
# 2020-10-01 09:32:36,353 - INFO - downloader - image #2	https://professionaldevelopment.school.nz/wp-content/uploads/2015/05/item-60.jpg
# 2020-10-01 09:32:36,855 - INFO - downloader - image #3	https://c1.staticflickr.com/7/6159/6170656527_9ef42dc0b4_b.jpg
# 2020-10-01 09:32:41,322 - INFO - downloader - image #23	https://i.pinimg.com/originals/25/a7/d1/25a7d18aa50ecc12b8a451942464e2cb.jpg
# 2020-10-01 09:32:41,402 - INFO - downloader - image #24	https://i.pinimg.com/originals/07/eb/e8/07ebe89d62440579a175bf93c9436f25.jpg
# 2020-10-01 09:32:42,868 - INFO - downloader - image #25	https://img.memecdn.com/the-long-yellow-things-are-next-to-the-round-green-things_o_6851897.jpg
# 2020-10-01 09:32:43,137 - ERROR - downloader - Response status code 400, file https://c.shld.net/rpx/i/s/pi/mp/37933/prod_4152989926?src=http%3A%2F%2Fimages.qgold.com%2Fqgrepo%2FTC232--8.jpg
# 2020-10-01 09:32:43,400 - INFO - downloader - image #26	http://www.nancyfreemanstudio.com/uploads/1/1/4/8/11481367/549167574.jpg
# 2020-10-01 09:32:44,048 - ERROR - downloader - Response status code 404, file http://www.castleandthings.com.au/wp-content/uploads/2015/11/yellow_penny_web_960.jpg
# 2020-10-01 09:32:44,666 - INFO - downloader - image #27	http://www.thenaturalsapphirecompany.com/blog/wp-content/uploads/2015/03/round-yellow-sapphire-0.9000-cts.jpg
# 2020-10-01 09:32:45,116 - INFO - downloader - image #28	https://natureformysoul.com/wp-content/uploads/galleries/post-8199/round2-0071.jpg
# 2020-10-01 09:32:45,762 - INFO - downloader - image #29	http://cdn.notonthehighstreet.com/system/product_images/images/000/624/328/original_Funky%20Round%20Yellow.jpg
# 2020-10-01 09:32:46,111 - INFO - downloader - image #30	http://www.chinawhisper.com/wp-content/uploads/2015/04/Peruvian-groundcherry.jpg
# 2020-10-01 09:32:46,761 - INFO - downloader - image #31	http://bestdecorthings.com/wp-content/uploads/2016/02/grey-yellow-area-rug-150x150.jpg
# 2020-10-01 09:32:46,851 - INFO - downloader - image #32	https://i.pinimg.com/originals/b8/f0/4f/b8f04f94740b20b5c4706d5a4543d832.jpg
# 2020-10-01 09:32:46,974 - INFO - downloader - downloaded images reach max num, thread downloader-001 is ready to exit
# 2020-10-01 09:32:46,975 - INFO - downloader - thread downloader-001 exit
# 2020-10-01 09:32:47,304 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# # Process Images

# %%
import cv2
import matplotlib.pyplot as plt
import os

# List Files
# os.listdir returns a list of all files in output_directory 
# the list contains only filenames - to access a file from the list you need to
# concat output_directory + inputFiles[n]
# 

inputFiles = os.listdir(output_directory)

# Add Code to handle Files
# הוסיפו קוד שיבצע פעולות עיבוד/עריכה על התמונות שנאספו
# ADD CODE HERE
#

# Display Results
# הצגת הדימויים בפורמט גריד 
# בדוגמא הנוספת יש קטעי קוד שיכולים לשמש לפורמטים שונים של תצוגה או יצוא
# כרגע הדוגמא מציגה 21 דוגמאות מהקבצים שהורדו 

fig, axs = plt.subplots(7, 3, figsize=(20, 20))
fig.subplots_adjust(hspace = .5, wspace=.001)
axarr = axs.ravel()

for i in range(21):
  tmp = cv2.imread(output_directory + inputFiles[i])
  tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)
  axarr[i].imshow(tmp)
  axarr[i].axis('off')
