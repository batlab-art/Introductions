# %% [markdown]
# <a href="https://colab.research.google.com/github/batlab-art/Introductions/blob/master/Open_Cv_Scraping_For_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# !pip install icrawler
# Out:
# Collecting icrawler
#   Downloading https://files.pythonhosted.org/packages/89/de/71d154b1fe181ee1a4afae5d10451856ef4689b3fd72d93cc55f31d2886a/icrawler-0.6.3-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.3

# %% [markdown]
# # Fetch Images
# ### BingImageCrawler:
# **Type** – “photo”, “clipart”, “linedrawing”, “transparent”, “animated"
# **Color** – “color”, “blackandwhite”, “red”, “orange”, “yellow”, “green”, “teal”, “blue”, “purple”, “pink”, “white”, “gray”, “black”, “brown
# **Size** – “large”, “medium”, “small” or larger than a given size (e.g. “>640x480”).
# **License** – “creativecommons”, “publicdomain”, “noncommercial”, “commercial”, “noncommercial,modify”, “commercial,modify”.
# **Layout** – “square”, “wide”, “tall”.
# **People** – “face”, “portrait”.
# **Date** – “pastday”, “pastweek”, “pastmonth”, “pastyear”.
#
# https://icrawler.readthedocs.io/en/latest/builtin.html

# %%
# !rm /content/download/*

from icrawler.builtin import BingImageCrawler

keywordText = 'squre purple spot'  #@param {type: "string"}
num_images =   32#@param {type: "number"}
output_directory = '/content/download/'  #@param {type: "string"}


bing_crawler = BingImageCrawler(storage={'root_dir': 'download'})
bing_crawler.crawl(keyword=keywordText, max_num=num_images)
# Out:
# rm: cannot remove '/content/download/*': No such file or directory
# 2020-09-30 12:51:44,666 - INFO - icrawler.crawler - start crawling...
# 2020-09-30 12:51:44,667 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-30 12:51:44,673 - INFO - feeder - thread feeder-001 exit
# 2020-09-30 12:51:44,674 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-30 12:51:44,680 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-30 12:51:45,278 - INFO - parser - parsing result page https://www.bing.com/images/async?q=squre purple spot&first=0
# 2020-09-30 12:51:45,577 - INFO - downloader - image #1	https://thumbs.dreamstime.com/z/square-background-abstract-watercolor-purple-spots-square-background-abstract-watercolor-purple-spots-white-background-126710856.jpg
# 2020-09-30 12:51:45,646 - INFO - downloader - image #2	https://thumbs.dreamstime.com/z/square-spot-purple-stage-vector-velvet-one-white-light-transparent-background-eps-layered-editable-blank-theater-88098920.jpg
# 2020-09-30 12:51:53,510 - INFO - downloader - image #21	https://i.pinimg.com/originals/a8/a9/aa/a8a9aa3aef92e3f6f9f44ce09e08e4eb.jpg
# 2020-09-30 12:51:54,082 - INFO - downloader - image #22	https://images.motorcycleid.com/oracle-lighting/items/5777-007-front-view.jpg
# 2020-09-30 12:51:54,928 - INFO - downloader - image #23	http://cdn4.fast-serve.net/cdn/changingbedrooms/Plum-Purple-Spots-Aura-100-Cotton-Continental-Eu-Square-Pillowcase-65x65cm_277_6GMPN.jpg
# 2020-09-30 12:51:55,325 - INFO - downloader - image #24	https://img0.etsystatic.com/019/0/6314314/il_570xN.491969124_cnem.jpg
# 2020-09-30 12:51:55,495 - INFO - downloader - image #25	https://i.pinimg.com/originals/b2/c8/a5/b2c8a522d768fc26d77447a4478d48ae.jpg
# 2020-09-30 12:51:55,574 - INFO - downloader - image #26	https://i.ebayimg.com/images/g/klkAAOxyOlhSwIBu/s-l300.jpg
# 2020-09-30 12:51:55,825 - INFO - parser - parsing result page https://www.bing.com/images/async?q=squre purple spot&first=20
# 2020-09-30 12:51:56,241 - INFO - downloader - image #27	https://ss.beddinginn.com/images/product/11/11104/11104698_2.jpg
# 2020-09-30 12:51:56,748 - INFO - downloader - image #28	https://sc01.alicdn.com/kf/H70dbd1ccbf604690851959916ec64cef9/236981014/H70dbd1ccbf604690851959916ec64cef9.jpg
# 2020-09-30 12:51:56,854 - INFO - downloader - image #29	https://images.motorcycleid.com/oracle-lighting/items/5777-007.jpg
# 2020-09-30 12:51:57,631 - INFO - downloader - image #30	http://cdn3.fast-serve.net/cdn/changingbedrooms/Plum-Purple-Spots-Aura-100-Cotton-Continental-Eu-Square-Pillowcase-65x65cm_277_6GMPM.jpg
# 2020-09-30 12:51:58,077 - INFO - downloader - image #31	https://sc02.alicdn.com/kf/H63ed06f9f5d24c2ab9ccd29dfed568d3z.jpg
# 2020-09-30 12:51:58,401 - INFO - downloader - image #32	https://c1.staticflickr.com/7/6035/6334795718_ae8b0433dd_b.jpg
# 2020-09-30 12:51:58,776 - INFO - downloader - downloaded images reach max num, thread downloader-001 is ready to exit
# 2020-09-30 12:51:58,777 - INFO - downloader - thread downloader-001 exit
# 2020-09-30 12:51:59,698 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# # Handle Images

# %%
import cv2
import matplotlib.pyplot as plt

# List Files
inputFiles = os.listdir(output_directory)

# Add Code to handle Files

# Display Results
fig, axs = plt.subplots(4,3, figsize=(20, 20))
fig.subplots_adjust(hspace = .5, wspace=.001)
axarr = axs.ravel()

for i in range(12):
  tmp = cv2.imread(output_directory + inputFiles[i])
  tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)
  axarr[i].imshow(tmp)
  axarr[i].axis('off')
