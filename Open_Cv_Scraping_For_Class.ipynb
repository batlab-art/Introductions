# %% [markdown]
# <a href="https://colab.research.google.com/github/batlab-art/Introductions/blob/master/Open_Cv_Scraping_For_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# !pip install icrawler
# Out:
# Requirement already satisfied: icrawler in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)

# %% [markdown]
# # Fetch Images
# ### BingImageCrawler:
# **Type** – “photo”, “clipart”, “linedrawing”, “transparent”, “animated"
# **Color** – “color”, “blackandwhite”, “red”, “orange”, “yellow”, “green”, “teal”, “blue”, “purple”, “pink”, “white”, “gray”, “black”, “brown
# **Size** – “large”, “medium”, “small” or larger than a given size (e.g. “>640x480”).
# **License** – “creativecommons”, “publicdomain”, “noncommercial”, “commercial”, “noncommercial,modify”, “commercial,modify”.
# **Layout** – “square”, “wide”, “tall”.
# **People** – “face”, “portrait”.
# **Date** – “pastday”, “pastweek”, “pastmonth”, “pastyear”.
#
# https://icrawler.readthedocs.io/en/latest/builtin.html

# %%
# !rm /content/download/*

from icrawler.builtin import BingImageCrawler

keywordText = 'apple pear '  #@param {type: "string"}
num_images =   32 #@param {type: "number"}
directory = 'download'  #@param {type: "string"}


bing_crawler = BingImageCrawler(storage={'root_dir': directory})
bing_crawler.crawl(keyword=keywordText, max_num=num_images)

output_directory = '/content/' + directory + '/'
# Out:
# 2020-09-30 18:09:48,874 - INFO - icrawler.crawler - start crawling...
# 2020-09-30 18:09:48,875 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-30 18:09:48,881 - INFO - feeder - thread feeder-001 exit
# 2020-09-30 18:09:48,883 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-30 18:09:48,889 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-30 18:09:49,455 - INFO - parser - parsing result page https://www.bing.com/images/async?q=apple pear &first=0
# 2020-09-30 18:09:50,576 - INFO - downloader - image #1	http://www.beyondkimchee.com/wp-content/uploads/blogger/_UOpVKba4CCo/S927o-SuHLI/AAAAAAAAAyo/6nAwSHD_khA/s1600/IMGP3311.jpg
# 2020-09-30 18:09:50,609 - INFO - downloader - image #2	http://4.bp.blogspot.com/-p0j5LMpxlRc/VNZx-NwZucI/AAAAAAAAT1A/b3bqoJDJPhE/s1600/Asian-Pear-4.jpg
# 2020-09-30 18:10:23,614 - INFO - downloader - image #19	https://www.thespruceeats.com/thmb/H2bs0D7QTqnpSqgKJL49cBuQEwg=/1500x1000/filters:no_upscale():max_bytes(150000):strip_icc()/ApplePearGin-122012049-56a172c05f9b58b7d0bf6003.jpg
# 2020-09-30 18:10:23,743 - INFO - downloader - image #20	https://usercontent2.hubstatic.com/6698919_f1024.jpg
# 2020-09-30 18:10:24,181 - INFO - downloader - image #21	http://cookingwithawallflower.com/wp-content/uploads/2016/11/Apple-Pear-Cider-2.jpg
# 2020-09-30 18:10:24,210 - INFO - downloader - image #22	https://i.ytimg.com/vi/X7-JRu93d0I/maxresdefault.jpg
# 2020-09-30 18:10:24,381 - INFO - downloader - image #23	https://broadbandnow.com/report/wp-content/uploads/2016/01/orange-pear-apple.jpg
# 2020-09-30 18:10:24,646 - INFO - downloader - image #24	http://cookingwithawallflower.com/wp-content/uploads/2016/11/Apple-Pear-Cider-4.jpg
# 2020-09-30 18:10:25,052 - INFO - downloader - image #25	http://img-aws.ehowcdn.com/350x235p/photos.demandstudios.com/getty/article/45/22/skd286284sdc_XS.jpg
# 2020-09-30 18:10:25,565 - INFO - downloader - image #26	http://www.theorganicdietitian.com/wp-content/uploads/2015/10/Pear-Apple-Sparkling-Cider-2.jpg
# 2020-09-30 18:10:25,906 - INFO - downloader - image #27	https://www.cmiapples.com/ecom_img/original-14-45-asian-pears.jpg
# 2020-09-30 18:10:26,316 - INFO - downloader - image #28	https://144f2a3a2f948f23fc61-ca525f0a2beaec3e91ca498facd51f15.ssl.cf3.rackcdn.com/uploads/food_portal_data/articles/article/hero_article_image/481/letterbox_Apples-pears-593x426.jpg
# 2020-09-30 18:10:26,384 - INFO - parser - no more page urls for thread parser-001 to parse
# 2020-09-30 18:10:26,385 - INFO - parser - thread parser-001 exit
# 2020-09-30 18:10:26,387 - INFO - downloader - image #29	https://thumbs.dreamstime.com/z/apple-pear-11527145.jpg
# 2020-09-30 18:10:31,393 - INFO - downloader - no more download task for thread downloader-001
# 2020-09-30 18:10:31,394 - INFO - downloader - thread downloader-001 exit
# 2020-09-30 18:10:31,940 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# # Process Images

# %%
import cv2
import matplotlib.pyplot as plt
import os

# List Files
inputFiles = os.listdir(output_directory)

# Add Code to handle Files

# Display Results
fig, axs = plt.subplots(7, 3, figsize=(20, 20))
fig.subplots_adjust(hspace = .5, wspace=.001)
axarr = axs.ravel()

for i in range(21):
  tmp = cv2.imread(output_directory + inputFiles[i])
  tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)
  axarr[i].imshow(tmp)
  axarr[i].axis('off')
